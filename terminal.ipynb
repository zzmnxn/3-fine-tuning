# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd '/content/drive/MyDrive/git'

# %%
# !git config --global user.email "github메일@gmail.com"
# !git config --global user.name "github계정"

# %%
# !git config --global --list

# %%
# !git remote add origin https://[토큰값]@github.com/[github계정]/[Repository이름].git

# %%
# !git remote add origin https://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@github.com/zzmnxn/3-fine-tuning.git

# %%
# !git remote -v

# %%
# !git clone https://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@github.com/zzmnxn/3-fine-tuning.git

# %%
cd 3-fine-tuning/
# !git checkout -b jimin

# %%
# !pip install nbstripout
# !nbstripout huggingface_basics.ipynb transformer.ipynb

# %%
cd "2-fine-tuning"

# %%
# !git checkout -b [본인브랜치명]

# %%
# !git add .
